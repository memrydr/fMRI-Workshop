# %%
from nilearn.plotting import plot_roi, plot_stat_map, plot_glass_brain
from glob import glob
# %matplotlib inline

# %%
plot_roi("/tmp/brain_sub-10159_T1w_mask.nii.gz", "/Users/saraappleton-knapp/Documents/CHEAR/fMRI_workshop/data1/sub-10159/anat/sub-10159_T1w.nii.gz",
         display_mode='y')

# %%
for map_file in glob("/Users/saraappleton-knapp/Documents/CHEAR/fMRI_workshop/data2/derivatives/task/Group/Example.gfeat/cope1.feat/thresh_zstat*.nii.gz")[:2]:
    plot_stat_map(map_file, threshold=1, cut_coords=(-35,10,-26))

# %%
plot_stat_map?
